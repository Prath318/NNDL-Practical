# %% [markdown]
# <a href="https://colab.research.google.com/github/Prath318/NNDL-Practical/blob/main/Practical_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
A=np.array([[2,2],[3,3]])
B=np.array([[2,2],[3,3]])

print("addion of matrix" , A+B)
# Out:
# addion of matrix [[4 4]
#  [6 6]]

# %%
print("multiplication of matrix ", np.matmul(A))
